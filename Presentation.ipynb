# %%
from file_reader import create_DataFrame 
from interact_graph import interactive_graph
from graphs import plot
from candlestickgraph import candle_stick
from dropdown import dropdown_stock
from predictions_module import *
from RSI import RSI

# %%
company,attribute,days = dropdown_stock()
stock_df = create_DataFrame(company)
interactive_graph(stock_df,company)
plot(attribute,stock_df,company)

# %%
plot('Close',stock_df,company)

# %%
candle_stick(stock_df)
# Out:
# /home/eshaanjoshi/.local/lib/python3.9/site-packages/mplfinance/_arg_validators.py:35: UserWarning:
#
#
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...

# %%
predict_open(stock_df,days)
predict_close(stock_df,days)
# Out:
# /home/eshaanjoshi/pythonstock/predictions_module.py:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/eshaanjoshi/pythonstock/predictions_module.py:54: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/eshaanjoshi/pythonstock/predictions_module.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
RSI(company,stock_df)
